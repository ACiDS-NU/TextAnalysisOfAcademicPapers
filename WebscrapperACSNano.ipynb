# %% [markdown]
# Import basic packages

# %%
import requests
import urllib.request
import time
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# Define scraping functions

# %%
def GetAbstract(link):
    # get abstract, keywords, and title given the url for an article
    
    # connect and get text from the website
    response = requests.get(link)
    
    # build a soup to parse the text data
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # find abstract
    pretextabstract = soup.find_all("p", class_= "articleBody_abstractText")
    
    # find keywords
    pretextkeywords = soup.find_all('meta', attrs = {'name' : 'keywords'})
    
    # return values after removing formatting stuff at the beginning and end
    return str(pretextabstract)[37:-5], str(pretextkeywords)[16:-20], soup.title.string

# %%
def GetArticles(issue):
    # find all articles given the url for an issue
    
    # connect and get text from the website
    response = requests.get(issue)
    
    # get the subset of data that contains articles (rather than perspectives or reviews) and make the soup
    soup = BeautifulSoup(response.text[response.text.find('<div class="subject">Articles</div> </h3>'):
          response.text.find('<div class="subject">Additions and Corrections</div>')], 'html.parser')
    
    # get all the relevant links
    temp = soup.find_all('div', class_='art_title linkable')
    
    # extract the links into an output list
    outputarticles = [] # initialize list
    for i in temp:
        tempstring = str(i) # convert to a string
        temptempstring = tempstring[tempstring.find('href'):] # find the beginning of the link
        
        # find the end of string and add it to the list
        outputarticles.append(temptempstring[temptempstring.find('/'):temptempstring.find('>') - 1]) 
        
    return outputarticles

# %%
def ScrapeIssue(volume,issue):
    # scrape an issue of ACS Nano given an volume and issue
    
    # get the list of articles
    articles = GetArticles('https://pubs.acs.org/toc/ancac3/' + str(volume) + '/' + str(issue))
    
    # initialize output dataframe
    outputdata = pd.DataFrame(columns = ['Title', 'Abstract', 'Keywords'])
    
    # scrape each article
    for article in articles:
        (ta,tk,tt) = GetAbstract('https://pubs.acs.org' + article)
        outputdata=outputdata.append(pd.DataFrame(index = [tt], data = {'Title' : tt, 
                                                                        'Abstract' : ta, 'Keywords' : tk}))
        
    return outputdata

# %% [markdown]
# Actual scrapping

# %%
# scrape volumes 8 through 12
for v in range(8, 12):
    for i in range(1, 13):
        temp = ScrapeIssue(v,i) # scrape the issue
        temp.to_csv('ACSNano_' + str(v) + '_' + str(i) + '.csv', index = False) # save it as a csv
        time.sleep(60*10) # wait ten minutes to avoid too many requests to the ACS website
        
# scrape volume 13, where there are currently only two issues
v=13
for i in range(1, 3):
    temp=ScrapeIssue(v, i) # scrape the issue
    temp.to_csv('ACSNano_' + str(v) + '_' + str(i) + '.csv', index = False) # save it as a csv
    time.sleep(60*10) # wait ten minutes

# %% [markdown]
# Combine into a single csv

# %%
# initialize dataframe
b = pd.DataFrame()

# import all the data
for v in range(8, 13):
    for i in range(1, 13):
        # load in the data
        temp = pd.read_csv('ACSNano_' + str(v) + '_' + str(i) + '.csv', encoding = 'unicode_escape')
        
        # set info about where the data came from
        temp['Year'] = v + 2006
        temp['Issue'] = v
        temp['Volume'] = i
        
        # add it to the dataframe
        b=b.append(temp)
        
# do the same thing for volume 13
v = 13
for i in range(1, 3):
    temp = pd.read_csv('ACSNano_13_' + str(i) + '.csv', encoding = 'unicode_escape')
    temp['Year'] = v + 2006
    temp['Issue'] = v
    temp['Volume'] = i
    b = b.append(temp)
    
    
# rearrange the columns
b = b[['Title', 'Abstract', 'Keywords', 'Year', 'Volume', 'Issue']]

# remove nans
b=b.dropna()

# cut the extra from the title
b['Title']=b['Title'].apply(lambda x:x[:-30])

# write to csv
b.to_csv('ACSNano_2014_2019.csv',index=False)

# %% [markdown]
# First attempts at interpretting the data (to be removed later)

# %%
# load in the data
temp = pd.read_csv('ACSNano_2014_2019.csv', encoding = 'unicode_escape')

# extract the keywords
keywords = temp['Keywords'].str.split(', ')
tempkeywords = keywords.tolist()

# make a single list with all the keywords
listofkeywords = []
for i in tempkeywords:
    listofkeywords += i

# %%
from collections import Counter

print('Average number of appearances per keyword: ' + str(len(listofkeywords) / len(Counter(listofkeywords))))

Counter(listofkeywords).most_common(1000)
# Out:
# Average number of appearances per keyword: 1.9862439188055696
# [('graphene', 394),
#  ('self-assembly', 358),
#  ('nanoparticles', 206),
#  ('scanning tunneling microscopy', 146),
#  ('MoS2', 114),
#  ('photoluminescence', 114),
#  ('nanoparticle', 113),
#  ('density functional theory', 112),
#  ('carbon nanotubes', 103),
#  ('drug delivery', 100),
#  ('graphene oxide', 96),
#  ('2D materials', 96),
#  ('quantum dots', 94),
#  ('gold nanoparticles', 91),
#  ('chemical vapor deposition', 91),
#  ('transition metal dichalcogenides', 85),
#  ('carbon nanotube', 80),
#  ('two-dimensional materials', 78),
#  ('plasmonics', 77),
#  ('nanomedicine', 75),
#  ('nanocrystals', 72),
#  ('atomic force microscopy', 72),
#  ('photothermal therapy', 70),
#  ('molecular dynamics', 67),
#  ('molybdenum disulfide', 67),
#  ('quantum dot', 66),
#  ('triboelectric nanogenerator', 64),
#  ('nanopore', 55),
#  ('photodynamic therapy', 55),
#  ('DNA nanotechnology', 55),
#  ('doping', 54),
#  ('perovskite', 51),
#  ('field-effect transistor', 50),
#  ('Raman spectroscopy', 49),
#  ('nanowires', 47),
#  ('DNA', 43),
#  ('DNA origami', 42),
#  ('silicon', 42),
#  ('AFM', 41),
#  ('DFT', 41),
#  ('electrochemistry', 40),
#  ('lithium-ion battery', 39),
#  ('hexagonal boron nitride', 39),
#  ('STM', 39),
#  ('microfluidics', 39),
#  ('fluorescence', 38),
#  ('nanowire', 38),
#  ('photodetector', 38),
#  ('black phosphorus', 38),
#  ('charge transfer', 37),
#  ('supercapacitor', 36),
#  ('defects', 36),
#  ('cancer', 35),
#  ('in situ TEM', 35),
#  ('nanotechnology', 34),
#  ('block copolymer', 34),
#  ('anode', 34),
#  ('lithium-ion batteries', 34),
#  ('photocatalysis', 34),
#  ('photoacoustic imaging', 34),
#  ('gold', 33),
#  ('interface', 33),
#  ('nanostructures', 33),
#  ('nanofabrication', 33),
#  ('gold nanorods', 33),
#  ('mechanical properties', 32),
#  ('gold nanoparticle', 32),
#  ('energy storage', 32),
#  ('MXene', 32),
#  ('thin films', 31),
#  ('catalysis', 31),
#  ('biosensor', 31),
#  ('surface chemistry', 31),
#  ('transistor', 31),
#  ('flexible', 31),
#  ('flexible electronics', 31),
#  ('SERS', 31),
#  ('cancer therapy', 31),
#  ('heterostructure', 31),
#  ('nanocrystal', 31),
#  ('atomic layer deposition', 30),
#  ('nanocomposites', 30),
#  ('diffusion', 30),
#  ('TEM', 30),
#  ('chirality', 29),
#  ('core?shell', 29),
#  ('Raman', 29),
#  ('electronic structure', 28),
#  ('hydrogen evolution reaction', 28),
#  ('energy transfer', 28),
#  ('electrocatalysis', 28),
#  ('field-effect transistors', 27),
#  ('imaging', 27),
#  ('photovoltaics', 27),
#  ('plasmon', 27),
#  ('charge transport', 27),
#  ('hydrogel', 26),
#  ('oxygen reduction reaction', 26),
#  ('thin film', 26),
#  ('nanotoxicology', 25),
#  ('protein corona', 25),
#  ('nanorods', 25),
#  ('magnetic resonance imaging', 25),
#  ('transition metal dichalcogenide', 25),
#  ('supercapacitors', 25),
#  ('phosphorene', 25),
#  ('polymer', 24),
#  ('surface plasmon resonance', 24),
#  ('phase transition', 24),
#  ('transmission electron microscopy', 24),
#  ('topological insulator', 24),
#  ('single molecule', 24),
#  ('self-powered', 24),
#  ('WSe2', 24),
#  ('metal?organic frameworks', 23),
#  ('self-assembled monolayer', 23),
#  ('monolayer', 22),
#  ('inflammation', 22),
#  ('anisotropy', 22),
#  ('magnetic nanoparticles', 22),
#  ('heterostructures', 22),
#  ('exciton', 22),
#  ('liposomes', 22),
#  ('tumor microenvironment', 22),
#  ('tungsten disulfide', 22),
#  ('transition-metal dichalcogenides', 22),
#  ('scanning probe microscopy', 21),
#  ('nanostructure', 21),
#  ('multimodal imaging', 21),
#  ('scanning tunneling spectroscopy', 21),
#  ('directed self-assembly', 21),
#  ('block copolymers', 21),
#  ('water splitting', 21),
#  ('localized surface plasmon resonance', 21),
#  ('plasmonic', 20),
#  ('molecular electronics', 20),
#  ('nanomaterials', 20),
#  ('nanotubes', 20),
#  ('layer-by-layer assembly', 20),
#  ('near-infrared', 20),
#  ('WS2', 20),
#  ('photothermal effect', 20),
#  ('super-resolution microscopy', 20),
#  ('transient absorption', 19),
#  ('reactive oxygen species', 19),
#  ('biomaterials', 19),
#  ('strain', 19),
#  ('sensor', 19),
#  ('light-emitting diodes', 19),
#  ('intercalation', 19),
#  ('bioimaging', 19),
#  ('mobility', 19),
#  ('nanocomposite', 19),
#  ('wearable electronics', 18),
#  ('silver', 18),
#  ('photodetectors', 18),
#  ('nanosheets', 18),
#  ('surface plasmons', 18),
#  ('Fano resonance', 18),
#  ('nanofluidics', 18),
#  ('thermal conductivity', 18),
#  ('stability', 18),
#  ('reduced graphene oxide', 18),
#  ('liquid crystals', 18),
#  ('Li-ion battery', 18),
#  ('solar cells', 18),
#  ('TiO2', 18),
#  ('surface plasmon', 18),
#  ('colloidal quantum dots', 18),
#  ('on-surface synthesis', 18),
#  ('crystallization', 18),
#  ('single-walled carbon nanotubes', 17),
#  ('boron nitride', 17),
#  ('spintronics', 17),
#  ('biodistribution', 17),
#  ('solar cell', 17),
#  ('molecular dynamics simulations', 17),
#  ('plasmons', 17),
#  ('optoelectronics', 17),
#  ('perovskite solar cells', 17),
#  ('silver nanoparticles', 17),
#  ('electrospinning', 17),
#  ('lithium ion battery', 17),
#  ('electron transfer', 17),
#  ('surface-enhanced Raman scattering', 17),
#  ('energy harvesting', 17),
#  ('MoSe2', 17),
#  ('peptide', 17),
#  ('X-ray photoelectron spectroscopy', 16),
#  ('ultrasound', 16),
#  ('magnetoresistance', 16),
#  ('layered materials', 16),
#  ('oxidation', 16),
#  ('contact resistance', 16),
#  ('nanofibers', 16),
#  ('Auger recombination', 16),
#  ('nanoimprint lithography', 16),
#  ('self-assembled monolayers', 16),
#  ('breast cancer', 16),
#  ('hydrogen evolution', 16),
#  ('graphene nanoribbons', 16),
#  ('immunotherapy', 16),
#  ('molecular beam epitaxy', 16),
#  ('two-dimensional', 16),
#  ('van der Waals heterostructure', 16),
#  ('transition-metal dichalcogenide', 16),
#  ('grain boundaries', 16),
#  ('encapsulation', 16),
#  ('superhydrophobic', 16),
#  ('STEM', 16),
#  ('electroluminescence', 15),
#  ('growth mechanism', 15),
#  ('semiconductor', 15),
#  ('directed assembly', 15),
#  ('ionic liquid', 15),
#  ('molecular dynamics simulation', 15),
#  ('surface modification', 15),
#  ('resistive switching', 15),
#  ('EELS', 15),
#  ('transfer', 15),
#  ('Li-ion batteries', 15),
#  ('nanophotonics', 15),
#  ('iron oxide', 15),
#  ('CVD', 15),
#  ('nanoplatelets', 15),
#  ('heterojunction', 15),
#  ('biomimetic', 15),
#  ('self-healing', 15),
#  ('biosensors', 15),
#  ('silica', 15),
#  ('water', 15),
#  ('metal?organic framework', 15),
#  ('photovoltaic', 14),
#  ('stretchable electronics', 14),
#  ('electrodeposition', 14),
#  ('bacteria', 14),
#  ('Schottky barrier', 14),
#  ('copper', 14),
#  ('carbon', 14),
#  ('platinum', 14),
#  ('liquid crystal', 14),
#  ('band gap', 14),
#  ('cytotoxicity', 14),
#  ('nanosheet', 14),
#  ('lithium ion batteries', 14),
#  ('nanopores', 14),
#  ('gold nanorod', 14),
#  ('functionalization', 14),
#  ('bioinspired', 14),
#  ('silver nanowire', 14),
#  ('2D material', 14),
#  ('transport', 14),
#  ('epitaxial growth', 14),
#  ('MRI', 14),
#  ('hierarchical structure', 14),
#  ('targeted delivery', 14),
#  ('biomimetics', 14),
#  ('lithium?sulfur battery', 14),
#  ('excitons', 14),
#  ('peptides', 14),
#  ('polarization', 14),
#  ('single-molecule', 14),
#  ('metastasis', 14),
#  ('wound healing', 14),
#  ('controlled release', 13),
#  ('doxorubicin', 13),
#  ('exosomes', 13),
#  ('wetting', 13),
#  ('transparent', 13),
#  ('click chemistry', 13),
#  ('titanium dioxide', 13),
#  ('DNA sequencing', 13),
#  ('CdSe', 13),
#  ('toxicity', 13),
#  ('mass spectrometry', 13),
#  ('conductivity', 13),
#  ('graphene quantum dots', 13),
#  ('ZnO', 13),
#  ('composite', 13),
#  ('nanomechanics', 13),
#  ('polydopamine', 13),
#  ('patterning', 13),
#  ('synergistic effect', 13),
#  ('upconversion', 13),
#  ('strain sensor', 13),
#  ('aerogel', 13),
#  ('optical properties', 13),
#  ('inkjet printing', 13),
#  ('work function', 13),
#  ('electronic transport', 13),
#  ('membrane', 13),
#  ('nanofiber', 13),
#  ('nanomotors', 13),
#  ('FRET', 13),
#  ('electron microscopy', 13),
#  ('oxygen evolution reaction', 13),
#  ('lithium?sulfur batteries', 13),
#  ('sodium-ion batteries', 13),
#  ('semiconductor nanocrystals', 12),
#  ('crystal growth', 12),
#  ('silver nanowires', 12),
#  ('organic photovoltaics', 12),
#  ('gene delivery', 12),
#  ('biomineralization', 12),
#  ('aluminum', 12),
#  ('palladium', 12),
#  ('contrast agent', 12),
#  ('nanodiamond', 12),
#  ('graphene nanoribbon', 12),
#  ('siRNA', 12),
#  ('stretchable', 12),
#  ('protein engineering', 12),
#  ('nanomotor', 12),
#  ('force spectroscopy', 12),
#  ('ligand exchange', 12),
#  ('mechanism', 12),
#  ('targeting', 12),
#  ('tissue engineering', 12),
#  ('endocytosis', 12),
#  ('micelles', 12),
#  ('ultrafast spectroscopy', 12),
#  ('simulation', 12),
#  ('transient absorption spectroscopy', 12),
#  ('trion', 12),
#  ('mesenchymal stem cells', 12),
#  ('structural color', 12),
#  ('cation exchange', 12),
#  ('macrophages', 12),
#  ('scanning transmission electron microscopy', 12),
#  ('3D printing', 12),
#  ('tumor', 12),
#  ('perovskites', 12),
#  ('surface functionalization', 12),
#  ('biocompatibility', 12),
#  ('piezo-phototronic effect', 12),
#  ('molecular imaging', 12),
#  ('fluorescence microscopy', 12),
#  ('pancreatic cancer', 12),
#  ('metasurface', 12),
#  ('exfoliation', 12),
#  ('transfer printing', 11),
#  ('supramolecular chemistry', 11),
#  ('translocation', 11),
#  ('catalyst', 11),
#  ('zinc oxide', 11),
#  ('cellular uptake', 11),
#  ('nanotube', 11),
#  ('apoptosis', 11),
#  ('strain engineering', 11),
#  ('iron oxide nanoparticles', 11),
#  ('van der Waals epitaxy', 11),
#  ('vesicles', 11),
#  ('light-emitting diode', 11),
#  ('nanoplasmonics', 11),
#  ('fullerene', 11),
#  ('chemotherapy', 11),
#  ('synthesis', 11),
#  ('oxygen vacancy', 11),
#  ('enzyme', 11),
#  ('luminescence', 11),
#  ('superconductivity', 11),
#  ('plasmon resonance', 11),
#  ('single-molecule force spectroscopy', 11),
#  ('macrophage', 11),
#  ('fluorescence imaging', 11),
#  ('circular dichroism', 11),
#  ('interface engineering', 11),
#  ('in situ transmission electron microscopy', 11),
#  ('surface-enhanced Raman spectroscopy', 11),
#  ('Janus particles', 11),
#  ('adsorption', 11),
#  ('condensation', 11),
#  ('theranostics', 11),
#  ('aggregation-induced emission', 11),
#  ('two-dimensional material', 11),
#  ('hysteresis', 11),
#  ('machine learning', 11),
#  ('theranostic', 10),
#  ('nucleation', 10),
#  ('density functional theory (DFT)', 10),
#  ('first-principles calculations', 10),
#  ('melanoma', 10),
#  ('thermal stability', 10),
#  ('polymeric micelles', 10),
#  ('superhydrophobicity', 10),
#  ('nonvolatile memory', 10),
#  ('biosensing', 10),
#  ('metal nanoparticles', 10),
#  ('interlayer coupling', 10),
#  ('super-resolution', 10),
#  ('single-molecule detection', 10),
#  ('field effect transistor', 10),
#  ('metamaterials', 10),
#  ('epitaxy', 10),
#  ('hierarchical structures', 10),
#  ('lipid bilayer', 10),
#  ('sodium-ion battery', 10),
#  ('core/shell', 10),
#  ('surface', 10),
#  ('carbon dots', 10),
#  ('aptamer', 10),
#  ('free-standing', 10),
#  ('nonlinear optics', 10),
#  ('Raman scattering', 10),
#  ('zebrafish', 10),
#  ('nanoconfinement', 10),
#  ('hot electrons', 10),
#  ('laser', 10),
#  ('stimuli-responsive', 10),
#  ('adhesion', 10),
#  ('photonic crystal', 10),
#  ('kinetics', 10),
#  ('micromotors', 10),
#  ('alloy', 10),
#  ('quantum confinement', 10),
#  ('PET imaging', 10),
#  ('gene therapy', 10),
#  ('colloids', 10),
#  ('oxygen vacancies', 10),
#  ('biexciton', 9),
#  ('porphyrin', 9),
#  ('liposome', 9),
#  ('etching', 9),
#  ('surface states', 9),
#  ('upconversion nanoparticles', 9),
#  ('conducting polymer', 9),
#  ('organic electronics', 9),
#  ('X-ray diffraction', 9),
#  ('purification', 9),
#  ('electron transport', 9),
#  ('nanobiotechnology', 9),
#  ('pulsed laser deposition', 9),
#  ('memristor', 9),
#  ('thermoelectric', 9),
#  ('SAXS', 9),
#  ('detection', 9),
#  ('self-organization', 9),
#  ('gold nanoclusters', 9),
#  ('tungsten diselenide', 9),
#  ('graphite', 9),
#  ('atomic force microscopy (AFM)', 9),
#  ('microRNA', 9),
#  ('polymer nanocomposites', 9),
#  ('blood?brain barrier', 9),
#  ('label-free', 9),
#  ('spectroscopy', 9),
#  ('sodium ion battery', 9),
#  ('tactile sensor', 9),
#  ('cathodoluminescence', 9),
#  ('bioconjugation', 9),
#  ('PEG', 9),
#  ('aggregation', 9),
#  ('silicon nanowire', 9),
#  ('nanotoxicity', 9),
#  ('ARPES', 9),
#  ('photolithography', 9),
#  ('symmetry breaking', 9),
#  ('silicon anode', 9),
#  ('magnetic resonance', 9),
#  ('perovskite solar cell', 9),
#  ('atherosclerosis', 9),
#  ('targeted drug delivery', 9),
#  ('piezotronic effect', 9),
#  ('polymers', 9),
#  ('porous silicon', 9),
#  ('molecular switch', 9),
#  ('electron energy loss spectroscopy', 9),
#  ('nanorod', 8),
#  ('dendrimer', 8),
#  ('conjugated polymer', 8),
#  ('scanning tunneling microscopy (STM)', 8),
#  ('defect', 8),
#  ('passivation', 8),
#  ('lead sulfide', 8),
#  ('FET', 8),
#  ('nanoporous materials', 8),
#  ('nanoimprinting', 8),
#  ('thermodynamics', 8),
#  ('nanopattern', 8),
#  ('lithography', 8),
#  ('diphenylalanine', 8),
#  ('?-hemolysin', 8),
#  ('hybrid', 8),
#  ('cell adhesion', 8),
#  ('XPS', 8),
#  ('autophagy', 8),
#  ('oxidative stress', 8),
#  ('ferroelectric', 8),
#  ('nanocellulose', 8),
#  ('ceria', 8),
#  ('solution process', 8),
#  ('colloidal nanocrystals', 8),
#  ('second harmonic generation', 8),
#  ('nanoparticle assembly', 8),
#  ('separation', 8),
#  ('tip-enhanced Raman spectroscopy', 8),
#  ('electron beam lithography', 8),
#  ('photocurrent', 8),
#  ('nanolithography', 8),
#  ('hydrogen', 8),
#  ('electron?phonon coupling', 8),
#  ('nanoporous', 8),
#  ('core?shell structure', 8),
#  ('magnetic hyperthermia', 8),
#  ('single-molecule fluorescence', 8),
#  ('phase transformation', 8),
#  ('superlattice', 8),
#  ('percolation', 8),
#  ('plasmonic nanoparticles', 8),
#  ('supramolecular', 8),
#  ('antibacterial', 8),
#  ('cisplatin', 8),
#  ('mesoporous silica nanoparticle', 8),
#  ('heterogeneous catalysis', 8),
#  ('h-BN', 8),
#  ('phosphorus', 8),
#  ('photothermal', 8),
#  ('tumor targeting', 8),
#  ('layer-by-layer', 8),
#  ('electrical conductivity', 8),
#  ('ligands', 8),
#  ('nanoantennas', 8),
#  ('nitrogen doping', 8),
#  ('photoresponse', 8),
#  ('nanoclusters', 8),
#  ('scanning electron microscopy', 8),
#  ('monolayer MoS2', 8),
#  ('battery', 8),
#  ('flexible device', 8),
#  ('morphology', 8),
#  ('electrocatalyst', 8),
#  ('nanoantenna', 8),
#  ('germanium', 8),
#  ('DFT calculations', 8),
#  ('liquid metal', 8),
#  ('electric double layer', 8),
#  ('in situ', 8),
#  ('nanochannel', 8),
#  ('single crystal', 8),
#  ('chitosan', 8),
#  ('copper sulfide', 8),
#  ('energy conversion', 8),
#  ('CO2 reduction', 8),
#  ('quantum yield', 8),
#  ('rheology', 8),
#  ('cathode', 8),
#  ('phase engineering', 8),
#  ('extracellular vesicles', 8),
#  ('van der Waals heterostructures', 8),
#  ('pseudocapacitance', 8),
#  ('light trapping', 7),
#  ('nanoparticle synthesis', 7),
#  ('core?shell nanoparticles', 7),
#  ('organic semiconductor', 7),
#  ('low temperature', 7),
#  ('live-cell imaging', 7),
#  ('phase segregation', 7),
#  ('vesicle', 7),
#  ('nanopipette', 7),
#  ('absorption', 7),
#  ('mesoporous silica', 7),
#  ('layered material', 7),
#  ('synthetic biology', 7),
#  ('patchy particles', 7),
#  ('silicon carbide', 7),
#  ('assembly', 7),
#  ('PLGA', 7),
#  ('infrared', 7),
#  ('sorting', 7),
#  ('phase separation', 7),
#  ('graphene foam', 7),
#  ('tunneling', 7),
#  ('photoemission spectroscopy', 7),
#  ('phthalocyanine', 7),
#  ('cancer immunotherapy', 7),
#  ('contrast agents', 7),
#  ('field effect transistors', 7),
#  ('microscopy', 7),
#  ('fiber', 7),
#  ('composites', 7),
#  ('porous carbon', 7),
#  ('sintering', 7),
#  ('hybridization', 7),
#  ('Au nanoparticles', 7),
#  ('pentacene', 7),
#  ('transparent electrode', 7),
#  ('origami', 7),
#  ('actuator', 7),
#  ('hydrophobicity', 7),
#  ('second-harmonic generation', 7),
#  ('hypoxia', 7),
#  ('Kelvin probe force microscopy', 7),
#  ('DNA self-assembly', 7),
#  ('near-field', 7),
#  ('silicon nanowires', 7),
#  ('triboelectric nanogenerators', 7),
#  ('Monte Carlo simulations', 7),
#  ('collagen', 7),
#  ('targeted therapy', 7),
#  ('GaN', 7),
#  ('galvanic replacement', 7),
#  ('molybdenum diselenide', 7),
#  ('combination therapy', 7),
#  ('pH-responsive', 7),
#  ('metal oxide', 7),
#  ('molybdenum carbide', 7),
#  ('p?n junction', 7),
#  ('siRNA delivery', 7),
#  ('biodegradation', 7),
#  ('dopants', 7),
#  ('anode material', 7),
#  ('intracellular delivery', 7),
#  ('biofilm', 7),
#  ('thermophoresis', 7),
#  ('topological insulators', 7),
#  ('nanoimaging', 7),
#  ('triboelectrification', 7),
#  ('differentiation', 7),
#  ('Ullmann coupling', 7),
#  ('cellulose nanocrystals', 7),
#  ('cross-linking', 7),
#  ('HRTEM', 7),
#  ('electrochemical performance', 7),
#  ('lipid membrane', 7),
#  ('surfactants', 7),
#  ('DFT calculation', 7),
#  ('thermoelectrics', 7),
#  ('exciton localization', 7),
#  ('mesoporous', 7),
#  ('nanosphere lithography', 7),
#  ('interfaces', 7),
#  ('single-molecule imaging', 7),
#  ('band structure', 7),
#  ('nanoscale', 7),
#  ('coarse-grained modeling', 7),
#  ('membranes', 7),
#  ('point-of-care', 7),
#  ('dissolution', 7),
#  ('polyethylene glycol', 7),
#  ('diagnosis', 7),
#  ('printed electronics', 7),
#  ('sodium ion batteries', 7),
#  ('degradation', 7),
#  ('dopamine', 7),
#  ('Li?S battery', 7),
#  ('friction', 7),
#  ('multiplexing', 7),
#  ('spin?orbit coupling', 7),
#  ('PEDOT:PSS', 7),
#  ('nanowire array', 7),
#  ('proximity effect', 7),
#  ('grain boundary', 7),
#  ('ab initio calculations', 7),
#  ('molecular simulation', 7),
#  ('sensors', 7),
#  ('CMOS', 7),
#  ('Alzheimer?s disease', 6),
#  ('computed tomography', 6),
#  ('cyclodextrin', 6),
#  ('multifunctional', 6),
#  ('confinement', 6),
#  ('charge recombination', 6),
#  ('nanocarrier', 6),
#  ('polymersome', 6),
#  ('two-dimensional semiconductors', 6),
#  ('mitochondria', 6),
#  ('biomaterial', 6),
#  ('Monte Carlo', 6),
#  ('photoelectron spectroscopy', 6),
#  ('Ullmann reaction', 6),
#  ('vanadium dioxide', 6),
#  ('tungsten diselenides', 6),
#  ('hydrogenation', 6),
#  ('epitaxial graphene', 6),
#  ('seeded growth', 6),
#  ('DNA nanostructures', 6),
#  ('nanoelectronics', 6),
#  ('photoconductivity', 6),
#  ('mesoporous silica nanoparticles', 6),
#  ('internalization', 6),
#  ('photoemission', 6),
#  ('confocal microscopy', 6),
#  ('flexible memory', 6),
#  ('azobenzene', 6),
#  ('broadband', 6),
#  ('lithium storage', 6),
#  ('transformation', 6),
#  ('scanning tunneling microscope', 6),
#  ('kinesin', 6),
#  ('microsphere', 6),
#  ('colon cancer', 6),
#  ('blinking', 6),
#  ('cell uptake', 6),
#  ('dichalcogenides', 6),
#  ('artificial nacre', 6),
#  ('soft lithography', 6),
#  ('lysosomes', 6),
#  ('electric field', 6),
#  ('dewetting', 6),
#  ('noncontact atomic force microscopy', 6),
#  ('single-walled carbon nanotube', 6),
#  ('exciton dynamics', 6),
#  ('CNT', 6),
#  ('stiffness', 6),
#  ('stoichiometry', 6),
#  ('photoresponsivity', 6),
#  ('aberration-corrected scanning transmission electron microscopy', 6),
#  ('triboelectric effect', 6),
#  ('amyloid', 6),
#  ('Young?s modulus', 6),
#  ('molybdenum ditelluride', 6),
#  ('cadmium selenide', 6),
#  ('surface passivation', 6),
#  ('protein folding', 6),
#  ('live cell imaging', 6),
#  ('mesenchymal stem cell', 6),
#  ('nanochannels', 6),
#  ('magnetism', 6),
#  ('hydrogels', 6),
#  ('ferritin', 6),
#  ('RNA nanotechnology', 6),
#  ('redox cycling', 6),
#  ('nanotribology', 6),
#  ('organic molecules', 6),
#  ('flow cytometry', 6),
#  ('polymerization', 6),
#  ('organic field-effect transistors', 6),
#  ('DNAzyme', 6),
#  ('boron nitride nanotubes', 6),
#  ('PbS', 6),
#  ('metasurfaces', 6),
#  ('E. coli', 6),
#  ('trapping', 6),
#  ('surface patterning', 6),
#  ('traps', 6),
#  ('angiogenesis', 6),
#  ('silicene', 6),
#  ('hot carriers', 6),
#  ('radiotherapy', 6),
#  ('fibers', 6),
#  ('colloidal synthesis', 6),
#  ('MXenes', 6),
#  ('electronic properties', 6),
#  ('electron energy-loss spectroscopy', 6),
#  ('piezoelectric', 6),
#  ('positron emission tomography', 6),
#  ('2D crystals', 6),
#  ('polypyrrole', 6),
#  ('nanoindentation', 6),
#  ('small-angle X-ray scattering', 6),
#  ('myocardial infarction', 6),
#  ('amyloid fibrils', 6),
#  ('ultrafast', 6),
#  ('ReS2', 6),
#  ('photostability', 6),
#  ('surface science', 6),
#  ('wurtzite', 6),
#  ('Kondo effect', 6),
#  ('supramolecular assembly', 6),
#  ('ionic liquids', 6),
#  ('two-photon absorption', 6),
#  ('structure', 6),
#  ('X-ray absorption spectroscopy', 6),
#  ('flexible devices', 6),
#  ('vaccine', 6),
#  ('high efficiency', 6),
#  ('neuromorphic computing', 6),
#  ('single-cell analysis', 6),
#  ('surface coverage', 6),
#  ('sol?gel', 6),
#  ('localized surface plasmon', 6),
#  ('size', 6),
#  ('phototransistor', 6),
#  ('growth', 6),
#  ('angle-resolved photoemission spectroscopy', 6),
#  ('electrical transport', 6),
#  ('immunoassay', 6),
#  ('piezoelectricity', 6),
#  ('liquid-phase exfoliation', 6),
#  ('synergistic therapy', 6),
#  ('pressure sensor', 6),
#  ('nanoribbons', 6),
#  ('nanoreactor', 6),
#  ('efficiency', 6),
#  ('exosome', 6),
#  ('diabetes', 6),
#  ('thin-film transistors', 6),
#  ('cell migration', 6),
#  ('scanning tunneling microscopy/spectroscopy', 6),
#  ('radiosensitization', 6),
#  ('glass transition', 6),
#  ('self-propulsion', 6),
#  ('graphitic carbon nitride', 6),
#  ('electronic coupling', 6),
#  ('colloidal assembly', 6),
#  ('dissipative particle dynamics', 6),
#  ('chiral', 6),
#  ('NEMS', 6),
#  ('prostate cancer', 6),
#  ('photonic crystals', 6),
#  ('electronic skin', 6),
#  ('regenerative medicine', 5),
#  ('dual emission', 5),
#  ('Au25', 5),
#  ('cytoskeleton', 5),
#  ('scanning photocurrent microscopy', 5),
#  ('hyaluronic acid', 5),
#  ('electrochromic', 5),
#  ('template', 5),
#  ('microwave', 5),
#  ('micelle', 5),
#  ('dextran', 5),
#  ('membrane protein', 5),
#  ('scanning ion conductance microscopy', 5),
#  ('surface plasmon polaritons', 5),
#  ('PbSe', 5),
#  ('colloidal quantum dot', 5),
#  ('inverter', 5),
#  ('electrostatics', 5),
#  ('photosynthesis', 5),
#  ('hybrid materials', 5),
#  ('amino acids', 5),
#  ('gas separation', 5),
#  ('nanoelectrode', 5),
#  ('microtubule', 5),
#  ('transistors', 5),
#  ('superlattices', 5),
#  ('time-resolved photoluminescence', 5),
#  ('rolling circle amplification', 5),
#  ('bismuth selenide', 5),
#  ('conjugated polymers', 5),
#  ('organic solar cells', 5),
#  ('X-ray absorption', 5),
#  ('in vitro', 5),
#  ('high-throughput', 5),
#  ('MOSFET', 5),
#  ('alignment', 5),
#  ('fullerenes', 5),
#  ('super-resolution fluorescence microscopy', 5),
#  ('low power', 5),
#  ('single molecules', 5),
#  ('energy level alignment', 5),
#  ('photobleaching', 5),
#  ('fibrosis', 5),
#  ('lysozyme', 5),
#  ('self-powered sensor', 5),
#  ('label-free detection', 5),
#  ('light-harvesting', 5),
#  ('surface reconstruction', 5),
#  ('CVD graphene', 5),
#  ('mechanics', 5),
#  ('semiconducting', 5),
#  ('quantum plasmonics', 5),
#  ('textile', 5),
#  ('porous materials', 5),
#  ('organic semiconductors', 5),
#  ('metamaterial', 5),
#  ('plasmonic nanostructures', 5),
#  ('paclitaxel', 5),
#  ('fuel cells', 5),
#  ('threshold voltage', 5),
#  ('electrodes', 5),
#  ('bottom-up', 5),
#  ('transparent conducting electrode', 5),
#  ('Monte Carlo simulation', 5),
#  ('negative differential resistance', 5),
#  ('silver nanoparticle', 5),
#  ('photoluminescence intermittency', 5),
#  ('spectral diffusion', 5),
#  ('Förster resonance energy transfer', 5),
#  ('focused ion beam', 5),
#  ('C60', 5),
#  ('ferroelectricity', 5),
#  ('scattering', 5),
#  ('subthreshold swing', 5),
#  ('electrolyte gating', 5),
#  ('electron tomography', 5),
#  ('thermal annealing', 5),
#  ('carbon nanomaterials', 5),
#  ('three-dimensional', 5),
#  ('dielectrophoresis', 5),
#  ('RNAi', 5),
#  ('activation', 5),
#  ('vacancy', 5),
#  ('in vivo', 5),
#  ('ZnO nanowire', 5),
#  ('single-particle tracking', 5),
#  ('boron', 5),
#  ('copper nanowires', 5),
#  ('defect engineering', 5),
#  ('biocompatible', 5),
#  ('carrier mobility', 5),
#  ('organic nanoparticles', 5),
#  ('hole mobility', 5),
#  ('contact electrification', 5),
#  ('TMDs', 5),
#  ('Au nanoparticle', 5),
#  ('bilayer graphene', 5),
#  ('on-surface reaction', 5),
#  ('polyelectrolyte multilayers', 5),
#  ('screening', 5),
#  ('nanoplate', 5),
#  ('conversion reaction', 5),
#  ('hydration', 5),
#  ('ellipsometry', 5),
#  ('photocatalyst', 5),
#  ('visible light', 5),
#  ('oxygen reduction', 5),
#  ('polyaniline', 5),
#  ('photoelectrochemical water splitting', 5),
#  ('supramolecular polymers', 5),
#  ('nanocluster', 5),
#  ('lattice strain', 5),
#  ('CO oxidation', 5),
#  ('stroke', 5),
#  ('magnetic anisotropy', 5),
#  ('anode materials', 5),
#  ('mesoporous materials', 5),
#  ('ionic conductivity', 5),
#  ('SnS2', 5),
#  ('nanosensor', 5),
#  ('fluorescence lifetime', 5),
#  ('core?shell nanostructure', 5),
#  ('glucose', 5),
#  ('recombination', 5),
#  ('rate capability', 5),
#  ('SrTiO3', 5),
#  ('2D nanomaterials', 5),
#  ('hybrid nanomaterials', 5),
#  ('tribotronics', 5),
#  ('bio-inspired', 5),
#  ('surface engineering', 5),
#  ('terahertz spectroscopy', 5),
#  ('nanogel', 5),
#  ('T cells', 5),
#  ('high temperature', 5),
#  ('cell tracking', 5),
#  ('conductive filament', 5),
#  ('network', 5),
#  ('capacitance', 5),
#  ('thin-film transistor', 5),
#  ('nanovesicle', 5),
#  ('flexible substrate', 5),
#  ('carrier dynamics', 5),
#  ('mechanochemistry', 5),
#  ('titanium oxide', 5),
#  ('lattice mismatch', 5),
#  ('phase diagram', 5),
#  ('ultrafast dynamics', 5),
#  ('ReSe2', 5),
#  ('silicon nanoparticles', 5),
#  ('strength', 5),
#  ('hyperthermia', 5),
#  ('proteins', 5),
#  ('surface energy', 5),
#  ('vibrational spectroscopy', 5),
#  ('artificial photosynthesis', 5),
#  ('Al2O3', 5),
#  ('coating', 5),
#  ('Ir(111)', 5),
#  ('PEEM', 5),
#  ('diagnostics', 5),
#  ('cancer diagnosis', 5),
#  ('disassembly', 5),
#  ('virus', 5),
#  ('near-infrared light', 5),
#  ('moisture', 5),
#  ('Staphylococcus aureus', 5),
#  ('2D', 5),
#  ('solution processing', 5),
#  ('nacre', 5),
#  ('lamellae', 5),
#  ('surface structure', 5),
#  ('SWCNT', 5),
#  ('bone regeneration', 5),
#  ('ambipolar', 5),
#  ('MBE', 5),
#  ('surface coating', 5),
#  ('hierarchical self-assembly', 5),
#  ('cell mechanics', 5),
#  ('whispering gallery mode', 5),
#  ('G-quadruplex', 5),
#  ('single-molecule magnets', 5),
#  ('electromagnetic generator', 5),
#  ('surface charge', 5),
#  ('dendritic cells', 5),
#  ('polymer nanoparticles', 5),
#  ('oxygen evolution', 5),
#  ('upconversion nanoparticle', 5),
#  ('structural colors', 5),
#  ('biomimicry', 5),
#  ('hydrogen bonding', 5),
#  ('nanopatterning', 5),
#  ('plasmon hybridization', 5),
#  ('in vivo imaging', 5),
#  ('phonons', 5),
#  ('coordination polymers', 5),
#  ('fluorescence correlation spectroscopy', 5),
#  ('ferroelectrics', 5),
#  ('tumor penetration', 5)]

# %%
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer

# vectorize the text data
vec = TfidfVectorizer()
X = vec.fit_transform(temp['Abstract'])

# convert to a dataframe
total_data = pd.DataFrame(X.toarray(), columns = vec.get_feature_names())

# %%
zz = temp['Keywords'].str.contains('graphene')

# %%
from sklearn.ensemble import RandomForestClassifier

graphene = RandomForestClassifier(random_state = 0)

graphene.fit(total_data.as_matrix(), zz)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=10, n_jobs=1, oob_score=False, random_state=0,
#             verbose=0, warm_start=False)
